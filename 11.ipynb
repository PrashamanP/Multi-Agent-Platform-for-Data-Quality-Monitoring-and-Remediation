# %%
import pandas as pd

f = pd.read_csv("data/input/npidata_pfile_20250929-20251005.csv")

f['Provider Business Practice Location Address State Name'].count()
# Out:
# /var/folders/dc/mhj323710m3599jy44jcbjtw0000gn/T/ipykernel_5241/815505421.py:3: DtypeWarning: Columns (17,24,32,68,72,76,80,84,85,87,88,89,90,91,92,93,94,95,96,97,98,99,100,101,102,103,104,105,106,123,127,131,135,137,138,139,141,142,143,145,146,147,149,150,151,153,154,155,157,158,159,161,162,163,165,166,169,170,171,173,174,177,178,179,181,185,187,189,193,195,197,199,201,205,209,213,217,221,223,225,230,234,237,241,245,312,320,322,323,324,325,326,327,328) have mixed types. Specify dtype option on import or set low_memory=False.
#   f = pd.read_csv("data/input/npidata_pfile_20250929-20251005.csv")
# 28780
